# %%
import phoebe
import numpy as np

b = phoebe.default_binary()
b.add_dataset('lc', times=np.linspace(0,1,11), fluxes=np.ones(11), sigmas=np.ones(11))

b.add_compute('phoebe', compute='compute2')
# Out:
# <ParameterSet: 39 parameters | datasets: _default, lc01>

# %%
b.add_solver('optimizer.differential_corrections', fit_parameters=['incl@binary'], compute='compute2')
# Out:
# <ParameterSet: 9 parameters | qualifiers: continue_from, steps, compute, comments, initial_values, use_server, fit_parameters, expose_lnprobabilities, deriv_method>

# %%
b.run_solver()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.16it/s]
# <ParameterSet: 11 parameters | qualifiers: adopt_distributions, adopt_values, steps, comments, singular_values, fitted_values, fitted_units, fitted_twigs, fitted_chi2, initial_values, adopt_parameters>
